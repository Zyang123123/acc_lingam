# %%
import numpy as np
import pandas as pd
import os

# 获取文件列表
files = [
    'causality_matrix_k25.csv',
    'causality_matrix_k50.csv',
    'causality_matrix_k100.csv',
    'causality_matrix_k200.csv',
    'causality_matrix_k400.csv',
    'causality_matrix_k800.csv'
]

# 文件路径前缀
file_prefix = '/mnt/data/'  # 请替换为实际的文件路径

def calculate_shd(matrix1, matrix2):
    """
    计算两个矩阵之间的结构化亟变距离 (SHD)。
    """
    if matrix1.shape != matrix2.shape:
        raise ValueError("The matrices must have the same shape to compute SHD.")
    
    # 计算差异矩阵
    difference_matrix = matrix1 != matrix2
    
    # 计算 SHD 为差异矩阵中不同元素的数量
    shd = np.sum(difference_matrix)
    return shd

# 逐对计算文件的 SHD
for i in range(len(files) - 1):
    file1 = os.path.join(file_prefix, files[i])
    file2 = os.path.join(file_prefix, files[i + 1])
    
    # 加载矩阵
    matrix1 = pd.read_csv(file1, header=None).values
    matrix2 = pd.read_csv(file2, header=None).values
    
    # 计算并输出 SHD
    try:
        shd_value = calculate_shd(matrix1, matrix2)
        print(f"SHD between {files[i]} and {files[i + 1]}: {shd_value}")
    except ValueError as e:
        print(f"Error comparing {files[i]} and {files[i + 1]}: {e}")

# %%
import pandas as pd

# Load the CSV file
file_path = './artificial_results_features_before.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe to understand its structure
data.head()
import matplotlib.pyplot as plt

# Extract relevant columns
features = data['features']
execution_time = data['total excution time']
# precomp_time = data['precomputation']
search_co_time = data['search causal order']
f1score = data['f1score']
accu = data['accuracy']
precision = data['precision']
recall = data['recall']

# Plotting
plt.figure(figsize=(8, 5))

plt.plot(features, search_co_time, '-o', label='Search Causal Order Time')
#plt.plot(features, execution_time, '-o', label='Total Execution Time')
# plt.plot(features, search_co_time+precomp_time, '-o', label='Total Time of two steps')
# plt.plot(features, precomp_time, '-s', label='Precomputation Time')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features')
# plt.ylabel('Execution Time (seconds)')
# plt.title('Execution Time vs. Features')
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels
#plt.savefig('./execution_time_vs_features_1.pdf')
plt.savefig('./execution_time_vs_features_1_before.pdf')
# Show the plot
plt.show()


# Plotting
plt.figure(figsize=(8, 5))
plt.plot(features, execution_time, '-o', label='Total Execution Time')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features')
# plt.ylabel('Execution Time (seconds)')
# plt.title('Execution Time vs. Features')
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels
#plt.savefig('./execution_time_vs_features_2.pdf')
plt.savefig('./execution_time_vs_features_2_before.pdf')
# Show the plot
plt.show()


# Plotting
plt.figure(figsize=(8, 5))
plt.plot(features, f1score, '-o', label='F1 score')
plt.plot(features, precision, '-s', label='Precision')
plt.plot(features, recall, '-^', label='Recall')
plt.plot(features, accu, '-d', label='Accuracy')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features', fontsize=20)
# plt.ylabel('Performance', fontsize=20)
# plt.title('Performance vs. Features', fontsize=24)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels

# plt.savefig('./performance_vs_features.pdf')
plt.savefig('./performance_vs_features_before.pdf')
# Show the plot
plt.show()

# %%
import pandas as pd

# Load the CSV file
file_path = './artificial_results_features.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe to understand its structure
data.head()
import matplotlib.pyplot as plt

# Extract relevant columns
features = data['features']
execution_time = data['total excution time']
precomp_time = data['precomputation']
search_co_time = data['search causal order']
f1score = data['f1score']
accu = data['accuracy']
precision = data['precision']
recall = data['recall']

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(features, search_co_time+precomp_time, '-o', label='Total Time of two steps')
plt.plot(features, precomp_time, '-s', label='Precomputation Time')
plt.plot(features, search_co_time, '-d', label='Search Causal Order Time')
#plt.plot(features, execution_time, '-o', label='Total Execution Time')


# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features')
# plt.ylabel('Execution Time (seconds)')
# plt.title('Execution Time vs. Features')
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels
plt.savefig('./execution_time_vs_features_1.pdf')

# Show the plot
plt.show()


# Plotting
plt.figure(figsize=(8, 5))
plt.plot(features, execution_time, '-o', label='Total Execution Time')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features')
# plt.ylabel('Execution Time (seconds)')
# plt.title('Execution Time vs. Features')
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels
plt.savefig('./execution_time_vs_features_2.pdf')
# Show the plot
plt.show()


# Plotting
plt.figure(figsize=(8, 5))
plt.plot(features, f1score, '-o', label='F1 score')
plt.plot(features, precision, '-s', label='Precision')
plt.plot(features, recall, '-^', label='Recall')
plt.plot(features, accu, '-d', label='Accuracy')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features', fontsize=20)
# plt.ylabel('Performance', fontsize=20)
# plt.title('Performance vs. Features', fontsize=24)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels

plt.savefig('./performance_vs_features.pdf')
# Show the plot
plt.show()

# %%
import pandas as pd

# Load the CSV file
file_path = './artificial_results_samples_before.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe to understand its structure
data.head()
import matplotlib.pyplot as plt

# Extract relevant columns
features = data['features']
samples = data['n_samples']
execution_time = data['total excution time']
# precomp_time = data['precomputation']
search_co_time = data['search causal order']
f1score = data['f1score']
accu = data['accuracy']
precision = data['precision']
recall = data['recall']

# Plotting
plt.figure(figsize=(8, 5))

plt.plot(samples, search_co_time, '-o', label='Search Causal Order Time')
#plt.plot(features, execution_time, '-o', label='Total Execution Time')
# plt.plot(features, search_co_time+precomp_time, '-o', label='Total Time of two steps')
# plt.plot(features, precomp_time, '-s', label='Precomputation Time')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features')
# plt.ylabel('Execution Time (seconds)')
# plt.title('Execution Time vs. Features')
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels
#plt.savefig('./execution_time_vs_features_1.pdf')
plt.savefig('./execution_time_vs_samples_1_before.pdf')
# Show the plot
plt.show()


# Plotting
plt.figure(figsize=(8, 5))
plt.plot(samples, execution_time, '-o', label='Total Execution Time')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features')
# plt.ylabel('Execution Time (seconds)')
# plt.title('Execution Time vs. Features')
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels
#plt.savefig('./execution_time_vs_features_2.pdf')
plt.savefig('./execution_time_vs_samples_2_before.pdf')
# Show the plot
plt.show()


# Plotting
plt.figure(figsize=(8, 5))
plt.plot(samples, f1score, '-o', label='F1 score')
plt.plot(samples, precision, '-s', label='Precision')
plt.plot(samples, recall, '-^', label='Recall')
plt.plot(samples, accu, '-d', label='Accuracy')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features', fontsize=20)
# plt.ylabel('Performance', fontsize=20)
# plt.title('Performance vs. Features', fontsize=24)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels

# plt.savefig('./performance_vs_features.pdf')
plt.savefig('./performance_vs_samples_before.pdf')
# Show the plot
plt.show()

# %%
import pandas as pd

# Load the CSV file
file_path = './artificial_results_samples_after.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe to understand its structure
data.head()
import matplotlib.pyplot as plt

# Extract relevant columns
features = data['features']
samples = data['n_samples']
execution_time = data['total excution time']
precomp_time = data['precomputation']
search_co_time = data['search causal order']
f1score = data['f1score']
accu = data['accuracy']
precision = data['precision']
recall = data['recall']

# Plotting
plt.figure(figsize=(8, 5))

plt.plot(samples, search_co_time+precomp_time, '-o', label='Total Time of two steps')
plt.plot(samples, precomp_time, '-s', label='Precomputation Time')
plt.plot(samples, search_co_time, '-d', label='Search Causal Order Time')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features')
# plt.ylabel('Execution Time (seconds)')
# plt.title('Execution Time vs. Features')
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels
#plt.savefig('./execution_time_vs_features_1.pdf')
plt.savefig('./execution_time_vs_samples_1_after.pdf')
# Show the plot
plt.show()


# Plotting
plt.figure(figsize=(8, 5))
plt.plot(samples, execution_time, '-o', label='Total Execution Time')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features')
# plt.ylabel('Execution Time (seconds)')
# plt.title('Execution Time vs. Features')
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels
#plt.savefig('./execution_time_vs_features_2.pdf')
plt.savefig('./execution_time_vs_samples_2_after.pdf')
# Show the plot
plt.show()


# Plotting
plt.figure(figsize=(8, 5))
plt.plot(samples, f1score, '-o', label='F1 score')
plt.plot(samples, precision, '-s', label='Precision')
plt.plot(samples, recall, '-^', label='Recall')
plt.plot(samples, accu, '-d', label='Accuracy')
# Set logarithmic scale for x-axis
plt.xscale('log')

# Adding labels and title
# plt.xlabel('Features', fontsize=20)
# plt.ylabel('Performance', fontsize=20)
# plt.title('Performance vs. Features', fontsize=24)
plt.legend(fontsize=16)
plt.xticks(fontsize=16)  # Adjust font size for x-axis tick labels
plt.yticks(fontsize=16)  # Adjust font size for y-axis tick labels

# plt.savefig('./performance_vs_features.pdf')
plt.savefig('./performance_vs_samples_after.pdf')
# Show the plot
plt.show()
